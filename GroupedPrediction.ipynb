# %% [markdown]
# # Create expert ranking from scrapped data

# %%
# export
import numpy as np
import pandas as pd
import json
from sklearn.preprocessing import MinMaxScaler as ScalerType
from sklearn.linear_model import Ridge as LinearModel
import sklearn

# %%
import pdb

# %% [markdown]
# ## Parameters

# %%
batch_size = 50
n_epochs = 50
label_column = 'combined_ranking'
meta_file = 'movie_expert_meta'
input_file = 'movies'

# %%
data = pd.read_csv('Data/' + input_file + '.csv', sep = ',', index_col = 'id')

# %%
data.head()
# Out:
#                            title certificate  runtime  year  \
# id
# 3778644  Solo: A Star Wars Story       PG-13      135  2018
# 5463162               Deadpool 2           R      119  2018
# 4154756   Avengers: Infinity War       PG-13      149  2018
# 1825683            Black Panther       PG-13      134  2018
# 6644200            A Quiet Place       PG-13       90  2018
#
#                               genre last_update  imdb_rating  imdb_votes  \
# id
# 3778644  Action, Adventure, Fantasy  10/06/2018           72       87482
# 5463162   Action, Adventure, Comedy  10/06/2018           81      145439
# 4154756  Action, Adventure, Fantasy  10/06/2018           88      368802
# 1825683   Action, Adventure, Sci-Fi  10/06/2018           75      326281
# 6644200       Drama, Horror, Sci-Fi  10/06/2018           79      121146
#
#          rt_critic_rating  rt_critic_votes  rt_audience_rating  \
# id
# 3778644                60               50                  65
# 5463162                67               46                  86
# 4154756                73               48                  91
# 1825683               100               50                  79
# 6644200               100               40                  84
#
#          rt_audience_votes  mc_rating  mc_votes
# id
# 3778644              32926         62        54
# 5463162              24309         66        51
# 4154756              43608         68        53
# 1825683              80444         88        55
# 6644200              15271         82        55

# %%
expert_meta = json.load(open('Data/' + meta_file + '.json', 'r'))

# %%
expert_meta
# Out:
# {'names': ['imdb', 'rt_critic', 'rt_audience', 'mc'],
#  'cols': ['_rating', '_votes']}

# %% [markdown]
# ## Loading in the data

# %% [markdown]
# First the number of votes take a natural logirithm. We only care if one object has a mannitude of ratings above another item.

# %%
# export
def logNVotes(data, expert_meta):
    for name in expert_meta['names']:
        col_name = name + '_votes'
        data[col_name] = data[col_name].map(lambda x : np.log(x) if x > 0 else x)

# %%
logNVotes(data, expert_meta)

# %%
data.head()
# Out:
#                            title certificate  runtime  year  \
# id
# 3778644  Solo: A Star Wars Story       PG-13      135  2018
# 5463162               Deadpool 2           R      119  2018
# 4154756   Avengers: Infinity War       PG-13      149  2018
# 1825683            Black Panther       PG-13      134  2018
# 6644200            A Quiet Place       PG-13       90  2018
#
#                               genre last_update  imdb_rating  imdb_votes  \
# id
# 3778644  Action, Adventure, Fantasy  10/06/2018           72   11.379188
# 5463162   Action, Adventure, Comedy  10/06/2018           81   11.887512
# 4154756  Action, Adventure, Fantasy  10/06/2018           88   12.818015
# 1825683   Action, Adventure, Sci-Fi  10/06/2018           75   12.695514
# 6644200       Drama, Horror, Sci-Fi  10/06/2018           79   11.704752
#
#          rt_critic_rating  rt_critic_votes  rt_audience_rating  \
# id
# 3778644                60         3.912023                  65
# 5463162                67         3.828641                  86
# 4154756                73         3.871201                  91
# 1825683               100         3.912023                  79
# 6644200               100         3.688879                  84
#
#          rt_audience_votes  mc_rating  mc_votes
# id
# 3778644          10.402018         62  3.988984
# 5463162          10.098602         66  3.931826
# 4154756          10.682996         68  3.970292
# 1825683          11.295317         88  4.007333
# 6644200           9.633711         82  4.007333

# %% [markdown]
# Everything that is negative 1 is missing and it is set at a NaN value. Everything else is scaled.

# %%
# export
scaler = ScalerType()

def converSeriesToInput(series):
    return series.where(series > 0).values.reshape(-1, 1)

def normaliseData(data, expert_meta):
    for name in expert_meta['names']:
        for col in expert_meta['cols']:
            col_name = name + col
            data[col_name] = data[col_name].astype(np.float64)
            scaler.fit(converSeriesToInput(data[col_name]))
            transformedInputToFloat = lambda x : scaler.transform([[x]])[0][0] if (x > 0) else np.nan
            data[col_name] = data[col_name].map(transformedInputToFloat)

# %%
normaliseData(data, expert_meta)

# %%
data.head()
# Out:
#                            title certificate  runtime  year  \
# id
# 3778644  Solo: A Star Wars Story       PG-13      135  2018
# 5463162               Deadpool 2           R      119  2018
# 4154756   Avengers: Infinity War       PG-13      149  2018
# 1825683            Black Panther       PG-13      134  2018
# 6644200            A Quiet Place       PG-13       90  2018
#
#                               genre last_update  imdb_rating  imdb_votes  \
# id
# 3778644  Action, Adventure, Fantasy  10/06/2018     0.233333    0.410446
# 5463162   Action, Adventure, Comedy  10/06/2018     0.533333    0.506826
# 4154756  Action, Adventure, Fantasy  10/06/2018     0.766667    0.683252
# 1825683   Action, Adventure, Sci-Fi  10/06/2018     0.333333    0.660026
# 6644200       Drama, Horror, Sci-Fi  10/06/2018     0.466667    0.472174
#
#          rt_critic_rating  rt_critic_votes  rt_audience_rating  \
# id
# 3778644          0.565217         0.581096            0.484375
# 5463162          0.641304         0.563874            0.812500
# 4154756          0.706522         0.572664            0.890625
# 1825683          1.000000         0.581096            0.703125
# 6644200          1.000000         0.535007            0.781250
#
#          rt_audience_votes  mc_rating  mc_votes
# id
# 3778644           0.459186   0.616162  0.970273
# 5463162           0.435715   0.656566  0.951086
# 4154756           0.480921   0.676768  0.963999
# 1825683           0.528287   0.878788  0.976433
# 6644200           0.399754   0.818182  0.976433

# %% [markdown]
# Initialise

# %%
data[label_column] = 0.5

# %%
data = data.sort_index()

# %% [markdown]
# ## Create expert object

# %% [markdown]
# First we create a function that will return a slice of the dataset from the main dataframe.

# %%
# export
def getDataIndexSlice(data : pd.DataFrame, i : int, batch_size: int):
    data_slice = data.iloc[i * batch_size : (i+1) * batch_size]
    return data_slice.to_dict(), data_slice.index

# %%
assert(len(getDataIndexSlice(data, 0, batch_size)[0][label_column]) == len(getDataIndexSlice(data, 0, batch_size)[1]))

# %%
# export
class Expert:
    
    def __init__(self, expert_name : str, col_suffixes : list, data : pd.DataFrame, 
            clf_type : sklearn.linear_model, batch_size: int, label_column: str, **kwargs):
        
        self.expert_name = expert_name
        self.data = data
        self.col_names = [expert_name + suf for suf in col_suffixes]
        self.label_col = label_column
        self.clf = clf_type(**kwargs)
        self.valid_index = self.createValidIndices(data)
        self.valid_len = len(self.valid_index)
        self.batch_size = batch_size
        self.n_batches = (self.valid_len + batch_size - 1) // batch_size
        
        self.data_view = None
        self.precision = 1.
        self.preds = np.ndarray(batch_size, dtype = np.float64)
        self.input_arr = np.ndarray(len(self.col_names), dtype = np.float64)
        self.preds.fill(np.nan)
        
        self.total_error = 0
        self.n_preds = 0
        self.current_index = 0
        self.compute_errors = True
        
    def resetCurrentIndex(self):
        self.current_index = 0
        self.total_error = 0.
        self.n_preds = 0
        
    ## Functions for getting training batches    
    
    def createValidIndices(self, data : pd.DataFrame):
        return data[np.all([data[col] > 0 for col in self.col_names], axis = 0)].index
    
    def getValidDataView(self):
        return np.array(self.data[self.col_names].loc[
                self.valid_index[self.current_index: np.min((self.current_index + self.batch_size, self.valid_len))]
        ])
    
    def getValidCombinedRating(self):
        return np.array(self.data[self.label_col].loc[
                self.valid_index[self.current_index: np.min((self.current_index + self.batch_size, self.valid_len))]
        ])
        
    def getBatch(self):
        train_x = self.getValidDataView()
        train_y = self.getValidCombinedRating()
        self.current_index += self.batch_size
        return train_x, train_y
        
    def trainBatch(self):
        train_x, train_y = self.getBatch()
        self.clf.fit(train_x, train_y)
        
    def trainAllData(self):
        self.resetCurrentIndex()
        for i in range(self.n_batches):
            self.trainBatch()
    
    ## Prediction functions for finding error and updating expert precision
    
    def getInputArrayFromDict(self, input_data : dict, input_index : pd.Index):
        self.input_arr[:] = [input_data[col][input_index] for col in self.col_names]
    
    def getPredictionErrorOnIndex(self, input_data : dict, input_indices : pd.Index, i : int):
        self.getInputArrayFromDict(input_data, input_indices[i])
        self.preds[i] = self.clf.predict(self.input_arr.reshape(1, -1))
        self.current_index += 1
        if self.compute_errors:
            self.total_error += (self.preds[i] - input_data[self.label_col][input_indices[i]])**2
            self.n_preds += 1
    
    def getPredictionForIndex(self, input_data : dict, input_indices : pd.Index, i : int):
        if not(self.current_index < self.valid_len):
            self.preds[i] = np.nan
        elif input_indices[i] != self.valid_index[self.current_index]:
            self.preds[i] = np.nan
        else:
            self.getPredictionErrorOnIndex(input_data, input_indices, i)
    
    def predictValues(self, input_data : dict, input_indices : pd.Index):
        n_input = len(input_indices)
        for i in range(n_input):
            self.getPredictionForIndex(input_data, input_indices, i)
        return self.preds[:n_input]
    
    def predictOnAllData(self, batches_in_data : int):
        self.resetCurrentIndex()
        for i in range(batches_in_data):
            input_data, input_indices = getDataIndexSlice(self.data, i, self.batch_size)
            self.predictValues(input_data, input_indices)
    
    def updatePrecision(self):
        if (self.n_preds == 0) or (self.total_error == 0):
            self.precision = 1.
        else:
            self.precision = 1/np.sqrt(self.total_error/self.n_preds)
        return self.total_error
            
    def __str__(self):
        return self.expert_name
    
    def __repr__(self):
        return self.expert_name

# %% [markdown]
# Create a stub `Expert` for testing called bert.

# %%
input_cols = ['_rating', '_votes']

# %%
bert = Expert('imdb', input_cols, data, LinearModel, batch_size, label_column,
               random_state = 0, max_iter = 1, tol = 0)

# %% [markdown]
# The expert can be queried to request the data for the indexes where the expert predicted. The number of valid indices should be be subset of the number of indices in the original dataset. A batch of valid predictions can be used for training. A valid entry must have all data fields (or `input_cols` as defined above) to have valid values to be suitable for training.

# %%
len(bert.valid_index)
# Out:
# 3044

# %%
assert(len(bert.valid_index) < len(data))

# %%
assert(np.linalg.norm(np.array(bert.getValidDataView().shape) - (batch_size, len(input_cols))) < 1e-7)

# %%
assert(np.linalg.norm(np.array(bert.getValidCombinedRating().shape) - (batch_size)) < 1e-7)

# %%
bert.trainBatch()

# %%
params = np.concatenate((bert.clf.coef_, [bert.clf.intercept_]), axis = 0); params
# Out:
# array([0. , 0. , 0.5])

# %% [markdown]
# At this point the final prediciton is a constant value of 0, 0 for the weight parameters and a constant intercept of 0.5 is optimal since the target rating is a constant 0.5. Any model that doesn't predict this is either unsuitable or it has not been set-up properly.

# %%
assert(np.linalg.norm(params - np.array([0., 0., 0.5])) < 1e-3)

# %%
input_data_batch = data.loc[data.index[:50]].to_dict()

# %% [markdown]
# Update the input array of the

# %%
bert.input_arr
# Out:
# array([2.12199579e-314, 6.36598737e-314])

# %%
bert.getInputArrayFromDict(input_data_batch, data.index[0])

# %%
bert.input_arr
# Out:
# array([0.56666667, 0.24106935])

# %%
assert(np.linalg.norm(bert.input_arr - (data.iloc[0]['imdb_rating'], data.iloc[0]['imdb_votes'])) < 1e-7)

# %%
bert.resetCurrentIndex()

# %%
stub_index = list(data.index[:batch_size]); stub_index.pop(0); stub_index.pop(-1);

# %%
bert.valid_index = stub_index
bert.valid_len = batch_size - 2

# %%
preds = bert.predictValues(input_data_batch, data.index[:50])

# %%
print(preds[:10], preds[-10:])
# Out:
# [nan 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5] [0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 nan]

# %%
assert(np.isnan(preds[0]))

# %%
assert(np.isnan(preds[-1]))

# %% [markdown]
# ## Evaluate data according to experts

# %%
# export
class ExpertEnsemble:
    
    def __init__(self, experts : list, data : pd.DataFrame,  scaler : sklearn.preprocessing, 
                 batch_size: int, label_col: str):

        self.experts = experts
        self.data = data
        self.scaler = scaler
        self.label_col = label_col
        
        self.n_experts = len(self.experts)
        self.experts_intiliased = False
        
        self.output_prediction = np.ndarray(batch_size, dtype = np.float64)
        self.batch_predictions = np.ndarray((self.n_experts, batch_size), dtype = np.float64)
        self.batch_weights = np.ndarray((self.n_experts, batch_size), dtype = np.float64)
        self.valid_len = len(self.data.index)
        self.batch_size = batch_size
        self.n_batches = (self.valid_len + batch_size - 1) // batch_size
        self.total_error = 0.
        self.weight_vector = np.ndarray((self.n_experts, batch_size), dtype = np.float64)
        self.weight_vector.fill(1/self.n_experts)
    
    def updateWeightVector(self):
        self.weight_vector[:, :] = np.array(
            [[expert.precision for expert in self.experts] for i in range(self.batch_size)], 
            dtype = np.float64).transpose()
        sum_weight = np.sum(self.weight_vector)
        if sum_weight == 0: 
            self.weight_vector.fill(1/self.n_experts)
        else:
            self.weight_vector /= sum_weight
    
    def updatePrecisions(self):
        self.turnOnErrors()
        self.total_error = 0.
        for expert in self.experts:
            expert.predictOnAllData(self.n_batches)
            self.total_error += expert.updatePrecision()
        self.updateWeightVector()
    
    def trainExperts(self):
        for expert in self.experts:
            expert.trainAllData()
            
    def turnOnErrors(self):
        for expert in self.experts: expert.compute_errors = True
            
    def turnOffErrors(self):
        for expert in self.experts: expert.compute_errors = False
            
    def resetAllIndices(self):
        for expert in self.experts: expert.resetCurrentIndex()
    
    def computeOutputPrediction(self, n_input : int):
        self.output_prediction[:n_input] = np.nansum(
            self.weight_vector[:, :n_input] * self.batch_predictions[:, :n_input], axis = 0)
    
    def setBatchPredictions(self, input_data : dict, input_indices: pd.Index, i : int, n_input: int):
        if self.experts_intiliased:
            for j in range(self.n_experts):
                self.batch_predictions[j, :n_input] = self.experts[j].predictValues(input_data, input_indices)
        else:
            for j in range(self.n_experts):
                self.batch_predictions[j, :n_input] = list(input_data[self.experts[j].expert_name + '_rating'].values())
    
    def scaleOutput(self):
        scaler.fit(converSeriesToInput(self.data[self.label_col]))
        scaleLabelColumn = lambda x : scaler.transform([[x]])[0][0]
        self.data[self.label_col] = self.data[self.label_col].map(scaleLabelColumn)
    
    def updateAggregatedPrediction(self):
        self.turnOffErrors()
        self.resetAllIndices()
        for i in range(self.n_batches):
            input_data, input_indices = getDataIndexSlice(self.data, i, self.batch_size)
            n_input = len(input_indices)
            self.setBatchPredictions(input_data, input_indices, i, n_input)
            self.computeOutputPrediction(n_input)
            self.data.at[input_indices, self.label_col] = self.output_prediction[:n_input]
        self.scaleOutput()
    
    def iterativelyPredictRanking(self, n_epochs : int):
        self.updateAggregatedPrediction()
        self.experts_intiliased = True
        for i in range(1, n_epochs + 1):
            self.trainExperts()
            self.updateAggregatedPrediction()
            self.updatePrecisions()
            print('Epoch', str(i), 'completed with total error', self.total_error)
            
    def __str__(self):
        return str(self.experts)
    
    def __repr__(self):
        return str(self.experts)

# %% [markdown]
# ## Create Iteration Algorithm

# %%
# export
def geneterateExperts(expert_meta, data, LinearModel, batch_size, label_column, **kwargs):
    return [Expert(name, expert_meta['cols'], data, LinearModel, batch_size, label_column, 
            **kwargs) for name in expert_meta['names']]

# %%
experts =  geneterateExperts(expert_meta, data, LinearModel, batch_size, label_column,
                             max_iter = 1, alpha = 1., fit_intercept = False)

# %%
kaggle_of_geese = ExpertEnsemble(experts, data, scaler, batch_size, label_column)

# %%
kaggle_of_geese.iterativelyPredictRanking(n_epochs)
# Out:
# Epoch 1 completed with total error 194.86090940117663
# Epoch 2 completed with total error 250.02010558526075
# Epoch 3 completed with total error 207.74764439092965
# Epoch 4 completed with total error 240.47971824302655
# Epoch 5 completed with total error 223.58126376852385
# Epoch 6 completed with total error 236.16336779175447
# Epoch 7 completed with total error 232.04011065758044
# Epoch 8 completed with total error 236.46547063385606
# Epoch 9 completed with total error 236.44493371678692
# Epoch 10 completed with total error 238.3749125200712
# Epoch 11 completed with total error 239.2773929605645
# Epoch 12 completed with total error 240.51074856519315
# Epoch 13 completed with total error 241.5056348616249
# Epoch 14 completed with total error 242.5123500719916
# Epoch 15 completed with total error 243.44299009356732
# Epoch 16 completed with total error 244.3414248223528
# Epoch 17 completed with total error 245.2000743074547
# Epoch 18 completed with total error 246.0290795643834
# Epoch 19 completed with total error 246.83143629437672
# Epoch 20 completed with total error 247.61184456295837
# Epoch 21 completed with total error 248.37386417552457
# Epoch 22 completed with total error 249.1209469822993
# Epoch 23 completed with total error 249.85620545843466
# Epoch 24 completed with total error 250.5825587813187
# Epoch 25 completed with total error 252.23967250996157
# Epoch 26 completed with total error 253.09415391904838
# Epoch 27 completed with total error 253.64445123362856
# Epoch 28 completed with total error 254.0480642863964
# Epoch 29 completed with total error 254.35056965633768
# Epoch 30 completed with total error 254.57693262554255
# Epoch 31 completed with total error 254.74643376747028
# Epoch 32 completed with total error 254.87337121644595
# Epoch 33 completed with total error 254.96842253302003
# Epoch 34 completed with total error 255.03957930188955
# Epoch 35 completed with total error 255.092835766547
# Epoch 36 completed with total error 255.1326869984877
# Epoch 37 completed with total error 255.1625024752999
# Epoch 38 completed with total error 255.1848067169734
# Epoch 39 completed with total error 255.2014903822909
# Epoch 40 completed with total error 255.21396892232391
# Epoch 41 completed with total error 255.22330172618717
# Epoch 42 completed with total error 255.230281518205
# Epoch 43 completed with total error 255.23550138351942
# Epoch 44 completed with total error 255.2394049894824
# Epoch 45 completed with total error 255.2423241975755
# Epoch 46 completed with total error 255.24450722128486
# Epoch 47 completed with total error 255.24613970026618
# Epoch 48 completed with total error 255.24736046946435
# Epoch 49 completed with total error 255.24827335672927
# Epoch 50 completed with total error 255.24895600808176

# %% [markdown]
# ## Test the Expert Ensemble

# %% [markdown]
# The error does not need to be minimised but we expect it to converge after sufficiently many epochs. The initial prediction is determined by every expert being equally weighted.

# %%
kaggle_of_geese
# Out:
# [imdb, rt_critic, rt_audience, mc]

# %% [markdown]
# Assert that the maximum is one.

# %%
assert(np.abs(np.max(data[label_column]) - 1) < 1e-5)

# %% [markdown]
# Show the highest rated film on the list. Sence check that it is good.

# %%
data.loc[data[label_column].idxmax()]
# Out:
# title                      The Dark Knight
# certificate                          PG-13
# runtime                                152
# year                                  2008
# genre                 Action, Crime, Drama
# last_update                     10/06/2018
# imdb_rating                       0.833333
# imdb_votes                        0.997274
# rt_critic_rating                  0.913043
# rt_critic_votes                   0.589197
# rt_audience_rating                  0.9375
# rt_audience_votes                 0.769966
# mc_rating                         0.818182
# mc_votes                          0.861032
# combined_ranking                         1
# Name: 468569, dtype: object

# %% [markdown]
# Asset that the minimum is zero.

# %%
assert(np.abs(np.min(data[label_column])) < 1e-5)

# %% [markdown]
# Look at the worst film on the list. Sense check that it is gabbage.

# %%
data.loc[data[label_column].idxmin()]
# Out:
# title                                Chaos
# certificate                              R
# runtime                                106
# year                                  2005
# genre                 Action, Crime, Drama
# last_update                     18/06/2018
# imdb_rating                              0
# imdb_votes                        0.293782
# rt_critic_rating                       NaN
# rt_critic_votes                        NaN
# rt_audience_rating                0.359375
# rt_audience_votes                 0.424877
# mc_rating                                0
# mc_votes                          0.368795
# combined_ranking                         0
# Name: 402910, dtype: object

# %% [markdown]
# Displays the entire list.

# %%
data.sort_values(by = [label_column], ascending = False)
# Out:
#                                                      title certificate  \
# id
# 468569                                     The Dark Knight       PG-13
# 111161                            The Shawshank Redemption           R
# 167260       The Lord of the Rings: The Return of the King       PG-13
# 68646                                        The Godfather   Not Rated
# 120737   The Lord of the Rings: The Fellowship of the Ring       PG-13
# 110912                                        Pulp Fiction           R
# 167261               The Lord of the Rings: The Two Towers       PG-13
# 1375666                                          Inception       PG-13
# 108052                                    Schindler's List           R
# 120815                                 Saving Private Ryan           R
# 910970                                              WALL·E   Not Rated
# 407887                                        The Departed           R
# 76759                   Star Wars: Episode IV - A New Hope          PG
# 137523                                          Fight Club     KNT/ENA
# 109830                                        Forrest Gump       PG-13
# 80684       Star Wars: Episode V - The Empire Strikes Back          PG
# 133093                                          The Matrix       KT/EA
# 1345836                              The Dark Knight Rises       PG-13
# 209144                                             Memento           R
# 102926                            The Silence of the Lambs   Not Rated
# 172495                                           Gladiator           R
# 266543                                        Finding Nemo   Not Rated
# 114369                                               Se7en     KNT/ENA
# 99685                                           Goodfellas   Not Rated
# 169547                                     American Beauty           R
# 71562                               The Godfather: Part II   Not Rated
# 245429                                       Spirited Away          PG
# 1853728                                   Django Unchained           R
# 1049413                                                 Up          PG
# 338013               Eternal Sunshine of the Spotless Mind           R
# ...                                                    ...         ...
# 120873                                       U.S. Marshals       KT/EA
# 211933                                               Awake           R
# 1448755                                       Killer Elite           R
# 1167638                                         22 Bullets   Not Rated
# 2140379                                          Self/less       PG-13
# 1924435                                      Let's Be Cops           R
# 365686                                            Revolver           R
# 3472226                                          Kung Fury   Not Rated
# 134273                                                 8MM     KNT/ENA
# 2178470                            Yeh Jawaani Hai Deewani   Not Rated
# 74896                                          The Message   Not Rated
# 6316138                          Ayla: The Daughter of War   Not Rated
# 1014763                                           Child 44           R
# 346631                                      Blood and Bone           R
# 914863                                         Unthinkable           R
# 2355495                                           Barefoot       PG-13
# 488085                                         Big Nothing           R
# 489664                                           Shattered           R
# 1174954                        Resident Evil: Degeneration           R
# 1937149                                           The Body   Not Rated
# 3042408                                           Who Am I   Not Rated
# 5541848                                    What the Health   Not Rated
# 6697582                                         Arif v 216   Not Rated
# 813980                                                  24   Not Rated
# 2101473                                      The Physician           R
# 2591814                                The Garden of Words   Not Rated
# 4176826                                    Look Who's Back   Not Rated
# 2800240                              Serial (Bad) Weddings   Not Rated
# 2987732                                 Suck Me Shakespeer   Not Rated
# 402910                                               Chaos           R
#
#          runtime  year                         genre last_update  imdb_rating  \
# id
# 468569       152  2008          Action, Crime, Drama  10/06/2018     0.833333
# 111161       142  1994                  Crime, Drama  10/06/2018     0.933333
# 167260       201  2003     Adventure, Drama, Fantasy  12/06/2018     0.800000
# 68646        175  1972                  Crime, Drama  10/06/2018     0.900000
# 120737       178  2001     Adventure, Drama, Fantasy  10/06/2018     0.766667
# 110912       154  1994                  Crime, Drama  10/06/2018     0.800000
# 167261       179  2002     Adventure, Drama, Fantasy  12/06/2018     0.733333
# 1375666      148  2010     Action, Adventure, Sci-Fi  10/06/2018     0.766667
# 108052       195  1993     Biography, Drama, History  12/06/2018     0.800000
# 120815       169  1998                    Drama, War  10/06/2018     0.700000
# 910970        98  2008  Animation, Adventure, Family  12/06/2018     0.633333
# 407887       151  2006        Crime, Drama, Thriller  10/06/2018     0.666667
# 76759        121  1977    Action, Adventure, Fantasy  10/06/2018     0.700000
# 137523       139  1999                         Drama  10/06/2018     0.766667
# 109830       142  1994                Drama, Romance  10/06/2018     0.766667
# 80684        124  1980    Action, Adventure, Fantasy  12/06/2018     0.766667
# 133093       136  1999                Action, Sci-Fi  10/06/2018     0.733333
# 1345836      164  2012              Action, Thriller  10/06/2018     0.633333
# 209144       113  2000             Mystery, Thriller  12/06/2018     0.666667
# 102926       118  1991        Crime, Drama, Thriller  10/06/2018     0.700000
# 172495       155  2000      Action, Adventure, Drama  12/06/2018     0.666667
# 266543       100  2003  Animation, Adventure, Comedy  12/06/2018     0.533333
# 114369       127  1995         Crime, Drama, Mystery  10/06/2018     0.700000
# 99685        146  1990       Biography, Crime, Drama  10/06/2018     0.733333
# 169547       122  1999                         Drama  12/06/2018     0.633333
# 71562        202  1974                  Crime, Drama  12/06/2018     0.833333
# 245429       125  2001  Animation, Adventure, Family  12/06/2018     0.700000
# 1853728      165  2012                Drama, Western  10/06/2018     0.633333
# 1049413       96  2009  Animation, Adventure, Comedy  12/06/2018     0.600000
# 338013       108  2004        Drama, Romance, Sci-Fi  12/06/2018     0.600000
# ...          ...   ...                           ...         ...          ...
# 120873       131  1998       Action, Crime, Thriller  18/06/2018     0.000000
# 211933        84  2007         Crime, Drama, Mystery  19/06/2018     0.000000
# 1448755      116  2011       Action, Crime, Thriller  18/06/2018     0.000000
# 1167638      117  2010       Action, Crime, Thriller  19/06/2018     0.066667
# 2140379      117  2015       Action, Mystery, Sci-Fi  18/06/2018     0.000000
# 1924435      104  2014                 Comedy, Crime  18/06/2018     0.000000
# 365686       111  2005          Action, Crime, Drama  19/06/2018     0.000000
# 3472226       31  2015         Short, Action, Comedy  16/06/2018     0.500000
# 134273       123  1999             Mystery, Thriller  19/06/2018     0.000000
# 2178470      160  2013        Comedy, Drama, Musical  01/07/2018     0.166667
# 74896        177  1976   Adventure, Biography, Drama  16/06/2018     0.566667
# 6316138      125  2017           Drama, History, War  16/06/2018     0.833333
# 1014763      137  2015        Crime, Drama, Thriller  18/06/2018     0.000000
# 346631        93  2009                 Action, Drama  19/06/2018     0.066667
# 914863        97  2010               Drama, Thriller  16/06/2018     0.200000
# 2355495       90  2014        Comedy, Drama, Romance  19/06/2018     0.033333
# 488085        86  2006       Comedy, Crime, Thriller  19/06/2018     0.100000
# 489664        95  2007         Crime, Drama, Mystery  19/06/2018     0.066667
# 1174954       97  2008     Animation, Action, Horror  19/06/2018     0.033333
# 1937149      108  2012             Mystery, Thriller  16/06/2018     0.366667
# 3042408      102  2014         Crime, Drama, Mystery  16/06/2018     0.366667
# 5541848       97  2017                   Documentary  16/06/2018     0.433333
# 6697582      125  2018                Comedy, Sci-Fi  18/06/2018     0.433333
# 813980        84  2008      Action, Adventure, Crime  16/06/2018     0.333333
# 2101473      150  2013     Adventure, Drama, History  16/06/2018     0.233333
# 2591814       46  2013     Animation, Drama, Romance  16/06/2018     0.366667
# 4176826      116  2015               Comedy, Fantasy  16/06/2018     0.200000
# 2800240       97  2014                        Comedy  16/06/2018     0.166667
# 2987732      119  2013                        Comedy  16/06/2018     0.166667
# 402910       106  2005          Action, Crime, Drama  18/06/2018     0.000000
#
#          imdb_votes  rt_critic_rating  rt_critic_votes  rt_audience_rating  \
# id
# 468569     0.997274          0.913043         0.589197            0.937500
# 111161     1.000000          0.934783         0.345752            1.000000
# 167260     0.936117          0.956522         0.576923            0.812500
# 68646      0.928163          0.945652         0.401918            1.000000
# 120737     0.938433          0.923913         0.563874            0.953125
# 110912     0.953380          0.913043         0.446031            0.968750
# 167261     0.917068          1.000000         0.568316            0.953125
# 1375666    0.974808          0.836957         0.596992            0.890625
# 108052     0.874556          1.000000         0.391841            0.984375
# 120815     0.878616          0.891304         0.529778            0.953125
# 910970     0.840994          0.956522         0.912690            0.859375
# 407887     0.874228          0.923913         0.596992            0.937500
# 76759      0.883118          0.891304         0.529778            0.968750
# 137523     0.958085          0.597826         0.507427            0.968750
# 109830     0.947874          0.673913         0.420708            0.953125
# 80684      0.869977          0.869565         0.437930            0.984375
# 133093     0.937398          0.663043         0.507427            0.796875
# 1345836    0.923680          0.728261         0.593131            0.875000
# 209144     0.867631          0.902174         0.549944            0.937500
# 102926     0.881456          0.869565         0.429498            0.953125
# 172495     0.896459          0.673913         0.568316            0.828125
# 266543     0.833389          0.978261         0.593131            0.812500
# 114369     0.906481          0.782609         0.653522            0.953125
# 99685      0.840682          0.945652         0.381246            0.984375
# 169547     0.861026          0.858696         0.559334            0.921875
# 71562      0.858390          0.902174         0.268360            0.984375
# 245429     0.745395          1.000000         0.540107            0.968750
# 1853728    0.895841          0.717391         0.581096            0.890625
# 1049413    0.827179          0.956522         0.572664            0.875000
# 338013     0.823963          0.891304         0.581096            0.937500
# ...             ...               ...              ...                 ...
# 120873     0.405434          0.195652         0.507427            0.296875
# 211933     0.362222          0.163043         0.622168            0.312500
# 1448755    0.460520          0.184783         0.767020            0.125000
# 1167638    0.200167          0.369565         0.286332            0.328125
# 2140379    0.381088          0.108696         0.787772            0.187500
# 1924435    0.466810          0.108696         0.670279            0.265625
# 365686     0.396571          0.097826         0.638439            0.343750
# 3472226    0.301825               NaN              NaN                 NaN
# 134273     0.457547          0.152174         0.672944            0.265625
# 2178470    0.215949               NaN         0.513245            0.453125
# 74896      0.254163               NaN              NaN                 NaN
# 6316138    0.133713               NaN              NaN                 NaN
# 1014763    0.321032          0.195652         0.672944            0.109375
# 346631     0.196116               NaN              NaN            0.593750
# 914863     0.389235               NaN              NaN                 NaN
# 2355495    0.131753          0.065217         0.401918            0.156250
# 488085     0.190965               NaN              NaN            0.421875
# 489664     0.192285               NaN              NaN            0.421875
# 1174954    0.185494               NaN              NaN            0.359375
# 1937149    0.241339               NaN              NaN                 NaN
# 3042408    0.240066               NaN              NaN                 NaN
# 5541848    0.137563               NaN              NaN                 NaN
# 6697582    0.132440               NaN              NaN                 NaN
# 813980     0.171326               NaN              NaN                 NaN
# 2101473    0.212459               NaN              NaN                 NaN
# 2591814    0.136197               NaN              NaN                 NaN
# 4176826    0.205236               NaN              NaN                 NaN
# 2800240    0.213283               NaN              NaN                 NaN
# 2987732    0.156718               NaN              NaN                 NaN
# 402910     0.293782               NaN              NaN            0.359375
#
#          rt_audience_votes  mc_rating  mc_votes  combined_ranking
# id
# 468569            0.769966   0.818182  0.861032          1.000000
# 111161            0.713717   0.797980  0.636847          0.990207
# 167260            0.997545   0.939394  0.877820          0.985407
# 68646             0.699042   1.000000  0.540275          0.968686
# 120737            0.746734   0.919192  0.814975          0.967541
# 110912            0.732349   0.939394  0.698051          0.964439
# 167261            0.745914   0.868687  0.861032          0.959725
# 1375666           0.679514   0.737374  0.885909          0.948352
# 108052            0.654332   0.929293  0.683764          0.929716
# 120815            0.722618   0.898990  0.824705          0.919341
# 910970            0.683332   0.949495  0.861032          0.916274
# 407887            0.699573   0.848485  0.861032          0.913425
# 76759             0.711449   0.898990  0.698051          0.913141
# 137523            0.730010   0.656566  0.824705          0.911124
# 109830            0.740094   0.818182  0.636847          0.908541
# 80684             0.727211   0.818182  0.711755          0.908046
# 133093            0.994461   0.727273  0.824705          0.907588
# 1345836           0.737954   0.777778  0.909070          0.896424
# 209144            0.648382   0.797980  0.814975          0.891716
# 102926            0.710260   0.848485  0.619628          0.889252
# 172495            0.996306   0.666667  0.916448          0.889181
# 266543            0.994538   0.898990  0.852312          0.887928
# 114369            0.664355   0.646465  0.668842          0.887454
# 99685             0.657594   0.888889  0.601479          0.885625
# 169547            0.691071   0.858586  0.804953          0.884587
# 71562             0.654305   0.848485  0.465367          0.884533
# 245429            0.638745   0.959596  0.877820          0.879673
# 1853728           0.657459   0.808081  0.885909          0.878479
# 1049413           0.737502   0.878788  0.843360          0.877718
# 338013            0.679796   0.888889  0.877820          0.877321
# ...                    ...        ...       ...               ...
# 120873            0.537496   0.464646  0.636847          0.152781
# 211933            0.612117   0.323232  0.582291          0.149391
# 1448755           0.457847   0.434343  0.761578          0.144112
# 1167638           0.256028        NaN       NaN          0.143249
# 2140379           0.433890   0.333333  0.772958          0.135661
# 1924435           0.508275   0.292929  0.683764          0.134988
# 365686            0.466762   0.242424  0.653226          0.132501
# 3472226                NaN        NaN       NaN          0.132418
# 134273            0.569935   0.181818  0.636847          0.131818
# 2178470           0.270228        NaN       NaN          0.125370
# 74896                  NaN        NaN       NaN          0.124575
# 6316138                NaN        NaN       NaN          0.123496
# 1014763           0.380434   0.404040  0.711755          0.122338
# 346631            0.277792        NaN       NaN          0.119898
# 914863                 NaN        NaN       NaN          0.112877
# 2355495           0.275756   0.212121  0.465367          0.111329
# 488085            0.405713        NaN       NaN          0.109313
# 489664            0.393153        NaN       NaN          0.102387
# 1174954           0.419292        NaN       NaN          0.085901
# 1937149                NaN        NaN       NaN          0.080869
# 3042408                NaN        NaN       NaN          0.080319
# 5541848                NaN        NaN       NaN          0.048812
# 6697582                NaN        NaN       NaN          0.046601
# 813980                 NaN        NaN       NaN          0.044295
# 2101473                NaN        NaN       NaN          0.042958
# 2591814                NaN        NaN       NaN          0.035498
# 4176826                NaN        NaN       NaN          0.033479
# 2800240                NaN        NaN       NaN          0.030589
# 2987732                NaN        NaN       NaN          0.006181
# 402910            0.424877   0.000000  0.368795          0.000000
#
# [3179 rows x 15 columns]

# %% [markdown]
# We expect the rating and the number of people voting to be positively correlated with the overall score that is given. It is preferable that one predicter does not dominate the others. Experts are weighted by their precision.

# %%
for expert in experts: print(expert, expert.precision, expert.clf.coef_, expert.clf.intercept_)
# Out:
# imdb 10.150383498882704 [0.37834119 0.8553767 ] 0.0
# rt_critic 6.055146644547952 [0.3834681  0.24964925] 0.0
# rt_audience 7.243911124923989 [0.42448126 0.25060935] 0.0
# mc 5.789519296555376 [0.32601684 0.26129987] 0.0

# %%
data[data['title'] == 'The Incredibles']
# Out:
#                   title certificate  runtime  year  \
# id
# 317705  The Incredibles          PG      115  2004
#
#                                genre last_update  imdb_rating  imdb_votes  \
# id
# 317705  Animation, Action, Adventure  10/06/2018          0.5    0.757555
#
#         rt_critic_rating  rt_critic_votes  rt_audience_rating  \
# id
# 317705          0.956522         0.568316            0.640625
#
#         rt_audience_votes  mc_rating  mc_votes  combined_ranking
# id
# 317705           0.992771    0.89899   0.87782          0.819962

# %% [markdown]
# ## Save the CSV

# %%
#data.to_csv('Data/' + input_file + '_combined_ranking.csv', mode = 'w')

# %% [markdown]
# ## Export

# %%
# !python notebook2script.py GroupedPrediction.ipynb
# Out:
# Converted GroupedPrediction.ipynb to Lib\nb_GroupedPrediction.py
